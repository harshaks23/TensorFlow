# %%
import numpy as np
import tensorflow as tf

# Import MNIST data very in tesnro flow
from tensorflow.examples.tutorials.mnist import input_data

# Store the MNIST data in one hot where each diigt
mnist = input_data.read_data_sets("mnist_data/", one_hot=True)
# Out:
# WARNING:tensorflow:From <ipython-input-1-c60fdfa6b9d4>:8: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From c:\users\genesis\miniconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From c:\users\genesis\miniconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\base.py:252: _internal_retry.<locals>.wrap.<locals>.wrapped_fn (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# ...

# %%
# i have used batch processing to see the

# %%
training_digits, training_labels = mnist.train.next_batch(5000)
test_digits, test_labels = mnist.test.next_batch(200)

training_digits_pl = tf.placeholder("float", [None, 784])

test_digit_pl = tf.placeholder("float", [784])

# Nearest Neighbor calculation using L1 distance
#u are negating the test data(only 1 in each case and then adding it each of the training data and you have traung data length vectors ie 500 vectors)
l1_distance = tf.abs(tf.add(training_digits_pl, tf.negative(test_digit_pl)))

#the whole vector is reduced to a single digit 
distance = tf.reduce_sum(l1_distance, axis=1)

#getting the min distance index that is the digit
# Prediction: Get min distance index (Nearest neighbor)
pred = tf.arg_min(distance, 0)

accuracy = 0.

# Initializing the variables
init = tf.global_variables_initializer()

with tf.Session() as sess:
    sess.run(init)

    # loop over test data
    for i in range(len(test_digits)):
        # Get nearest neighbor
        # getting the nearest digit index 
        nn_index = sess.run(pred,  feed_dict={training_digits_pl: training_digits, test_digit_pl: test_digits[i, :]})
        #print(training_labels[nn_index],"nn_index",nn_index,"--",training_labels[nn_index],np.argmax(training_labels[nn_index]))
        # Get nearest neighbor class label and compare it to its true label
        
        # here i get the one hot reperesetation (use the index and get it from the training lables and then use argmax)
        #argmax get the index of index in one hot representation if there is a 1 in that index
        print("Test", i, "Prediction:", np.argmax(training_labels[nn_index]), \
            "True Label:", np.argmax(test_labels[i]))

        # Calculate accuracy
        if np.argmax(training_labels[nn_index]) == np.argmax(test_labels[i]):
            accuracy += 1./len(test_digits)
        

    print("Done!")
    print("Accuracy:", accuracy)
# Out:
# Test 0 Prediction: 8 True Label: 8
# Test 1 Prediction: 7 True Label: 7
# Test 2 Prediction: 1 True Label: 1
# Test 3 Prediction: 5 True Label: 5
# Test 4 Prediction: 6 True Label: 6
# Test 5 Prediction: 7 True Label: 7
# Test 6 Prediction: 3 True Label: 3
# Test 7 Prediction: 5 True Label: 5
# Test 8 Prediction: 0 True Label: 0
# Test 9 Prediction: 1 True Label: 1
# Test 10 Prediction: 5 True Label: 5
# Test 11 Prediction: 5 True Label: 8
# Test 12 Prediction: 6 True Label: 6
# Test 13 Prediction: 8 True Label: 8
# Test 14 Prediction: 0 True Label: 0
# Test 15 Prediction: 7 True Label: 7
# Test 16 Prediction: 1 True Label: 1
# Test 17 Prediction: 7 True Label: 7
# Test 18 Prediction: 0 True Label: 0
# Test 19 Prediction: 9 True Label: 9
# Test 20 Prediction: 2 True Label: 2
# Test 21 Prediction: 1 True Label: 1
# Test 22 Prediction: 9 True Label: 9
# Test 23 Prediction: 1 True Label: 1
# Test 24 Prediction: 9 True Label: 9
# Test 25 Prediction: 0 True Label: 0
# ...

# %%
# Out:
# 784
